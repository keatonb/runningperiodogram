# %%
import numpy as np
import matplotlib.pyplot as plt
import lightkurve as lk
import astropy.units as u
from tqdm import tqdm
from runningperiodogram import runningperiodogram

# %%
#Dramatic example of sinusoid with sinusoidal frequency modulation
time = np.arange(0,30,1/48.)
flux = 1+ 0.03*np.sin(10*(time + np.sin(0.2*time))) + 0.03*np.random.randn(len(time))

#show data
plt.scatter(time,flux,s=2)
plt.xlabel('time (days)')
plt.ylabel('rel. flux')

#show periodogram
runningperiodogram(time,flux,filename='example.pdf')
# Out:
# Computing periodograms:   0%|          | 0/26 [00:00<?, ?it/s]/Users/keatonb/anaconda3/lib/python3.7/site-packages/astropy/timeseries/periodograms/lombscargle/implementations/fast_impl.py:93: RuntimeWarning: invalid value encountered in true_divide
#   tan_2omega_tau = (S2 - 2 * S * C) / (C2 - (C * C - S * S))
# /Users/keatonb/anaconda3/lib/python3.7/site-packages/astropy/units/quantity.py:477: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/keatonb/anaconda3/lib/python3.7/site-packages/astropy/timeseries/periodograms/lombscargle/implementations/fast_impl.py:122: RuntimeWarning: divide by zero encountered in true_divide
#   power = (YC * YC / CC + YS * YS / SS)
# /Users/keatonb/anaconda3/lib/python3.7/site-packages/astropy/timeseries/periodograms/lombscargle/implementations/fast_impl.py:122: RuntimeWarning: invalid value encountered in true_divide
#   power = (YC * YC / CC + YS * YS / SS)
# ...
